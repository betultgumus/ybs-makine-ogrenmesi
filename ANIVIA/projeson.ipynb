# %%
from IPython.display import HTML
import base64

# --- AYARLAR ---
resim_dosya_yolu = r'C:\Users\DELL\Desktop\Anivia_0.jpg'
yuvarlak_resim_yolu = r'C:\Users\DELL\Desktop\kapak.jpeg'
saydamlik_orani = 0.5

try:
    # 1. Arka plan resmini oku
    with open(resim_dosya_yolu, "rb") as f:
        encoded_bg = base64.b64encode(f.read()).decode()
    
    # 2. Yuvarlak içine gelecek resmi oku
    try:
        with open(yuvarlak_resim_yolu, "rb") as f:
            encoded_circle = base64.b64encode(f.read()).decode()
    except:
        encoded_circle = ""

    hero_html = f"""
    <link href="https://fonts.googleapis.com/css2?family=Cinzel:wght@400;900&display=swap" rel="stylesheet">

    <div class="hero-container">
        <div class="hero-overlay"></div>
        <div class="hero-content">
            <h1 class="elegant-ice-title">
                ANIVIA<br>
                GAME<br>
                INSIGHT
            </h1>

            <div class="ice-circle-wrapper">
                <div class="ice-circle-frame">
                    <div class="ice-circle-image" style="background-image: url('data:image/jpeg;base64,{encoded_circle}')"></div>
                </div>
            </div>
        </div>
    </div>

    <style>
    .hero-container {{
        position: relative;
        width: 100%;
        height: 1000px;
        background-image: url("data:image/jpeg;base64,{encoded_bg}");
        background-size: cover;
        background-position: center;
        border-radius: 30px;
        overflow: hidden;
        display: flex;
        justify-content: center;
        align-items: center;
        box-shadow: 0 25px 60px rgba(0,0,0,0.7);
    }}

    .hero-overlay {{
        position: absolute;
        inset: 0;
        background: linear-gradient(135deg, 
                    rgba(10, 25, 47, {saydamlik_orani}) 0%, 
                    rgba(20, 68, 106, {saydamlik_orani * 0.8}) 100%);
        z-index: 1;
    }}

    .hero-content {{
        position: relative;
        z-index: 2;
        text-align: center;
        perspective: 1500px;
        display: flex;
        flex-direction: column;
        align-items: center;
    }}

    .elegant-ice-title {{
        font-family: 'Cinzel', serif;
        font-weight: 900;
        font-size: 7.2em;
        line-height: 1.2;
        letter-spacing: 20px;
        color: #ffffff;
        margin: 120px 0 50px 0;
        text-transform: uppercase;
        text-shadow: 
            0 0 10px rgba(255, 255, 255, 0.8),
            0 0 30px rgba(0, 210, 255, 0.5);
        animation: iceGlowFloat 8s ease-in-out infinite;
    }}

    .ice-circle-wrapper {{
        perspective: 1000px;
        margin-top: 30px;
    }}

    .ice-circle-frame {{
        width: 280px;
        height: 280px;
        border-radius: 50%;
        border: 4px solid rgba(0, 210, 255, 0.6);
        box-shadow: 
            0 0 40px rgba(0, 210, 255, 0.5),
            inset 0 0 40px rgba(0, 210, 255, 0.2);
        overflow: hidden;
        background: rgba(255, 255, 255, 0.05);
    }}

    .ice-circle-image {{
        width: 100%;
        height: 100%;
        background-size: cover;
        background-position: center;
        border-radius: 50%;
    }}

    @keyframes iceGlowFloat {{
        0%, 100% {{
            transform: perspective(1000px) rotateX(12deg) translateY(0px) scale(1);
            text-shadow: 0 0 15px rgba(255, 255, 255, 0.6), 0 0 30px rgba(0, 210, 255, 0.4);
        }}
        50% {{
            transform: perspective(1000px) rotateX(6deg) translateY(-25px) scale(1.02);
            text-shadow: 0 0 30px rgba(255, 255, 255, 0.9), 0 0 50px rgba(0, 210, 255, 0.7);
        }}
    }}
    </style>
    """
    display(HTML(hero_html))

except Exception as e:
    print(f"Hata: {e}")
# Out:
#     <link href="https://fonts.googleapis.com/css2?family=Cinzel:wght@400;900&display=swap" rel="stylesheet">
#
#     <div class="hero-container">
#         <div class="hero-overlay"></div>
#         <div class="hero-content">
#             <h1 class="elegant-ice-title">
#                 ANIVIA<br>
#                 GAME<br>
#                 INSIGHT
#             </h1>
#
#             <div class="ice-circle-wrapper">
#                 <div class="ice-circle-frame">
#                     <div class="ice-circle-image" style="background-image: url('data:image/jpeg;base64,...')"></div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <style>
#     .hero-container {
#         position: relative;
#         width: 100%;
#         height: 1000px;
#         background-image: url("data:image/jpeg;base64,...");
#         background-size: cover;
#         background-position: center;
#         border-radius: 30px;
#         overflow: hidden;
# ...

# %%
from IPython.display import HTML
import base64

# --- AYARLAR ---
resim_dosya_yolu = r'C:\Users\DELL\Desktop\Anivia_0.jpg' 
saydamlik_orani = 0.5

def get_base64(path):
    try:
        with open(path, "rb") as f:
            return base64.b64encode(f.read()).decode()
    except Exception as e:
        return ""

bg_img = get_base64(resim_dosya_yolu)

# --- HTML TASLAĞI ---
html_template = """
<link href="https://fonts.googleapis.com/css2?family=Cinzel:wght@400;700;900&display=swap" rel="stylesheet">

<div class="hero-container">
    <div class="hero-overlay"></div>
    
    <div class="sticky-header">
        <h1 class="brand-title">ANIVIA GAME INSIGHT</h1>
    </div>
    
    <div class="hero-content">
        
        <div class="project-text">
            
            <h2 class="section-header">1. Veri Hikayesi: Dijital Oyun Pazarında "Dolarizasyon" ve Yerelleşme Krizi</h2>
            <p>
                <span class="highlight">Tarihsel Arka Plan:</span><br>
                Küresel oyun pazarı, 2025 yılı itibarıyla 1 milyar dolar barajını aşan Türkiye gibi gelişmekte olan pazarlarda büyük bir dönüşüm yaşamaktadır. 
                Özellikle 20 Kasım 2023 tarihinde Steam'in Türkiye'de TL yerine Dolar ($) üzerinden satış yapmaya başlaması, sektörde bir "milat" kabul edilir.
            </p>
            
            <p>
                Bu değişim, oyun fiyatlarının sadece döviz kuruna değil; oyunun türüne, geliştirici gücüne ve hedef kitlesine göre de aşırı dalgalanmasına neden olmuştur. 
            </p>
            
            <p>
                <span class="highlight">Gerçek Dünya Bağlamı:</span><br>
                Günümüzde bir oyun geliştiricisi, "Hangi fiyattan çıkış yapmalıyım?" sorusuna yanıt bulmakta zorlanmaktadır. İşte bu veri seti, pazarın bu "belirsizlik" dönemindeki fiyatlama davranışlarını yansıtmaktadır.
            </p>

            <h2 class="section-header">2. İş Probleminin Hikayesi ve Tanımı</h2>
            <p>
                <span class="highlight">İş Problemi:</span><br>
                "Bir dijital oyunun teknik ve içerik özelliklerine bakarak, Türkiye pazarındaki ideal satış fiyatını makine öğrenmesi ile nasıl tahmin edebiliriz?"
            </p>
            
            <div class="story-highlight">
                <p>
                    Yeni kurulan bir oyun stüdyosu olduğunuzu hayal edin. Elinizde harika bir aksiyon oyunu var ancak pazar o kadar dengesiz ki; 
                    yanlış bir fiyatlandırma, yıllarca süren emeğin boşa gitmesi demektir.
                </p>
            </div>

            <h2 class="section-header">3. Problem Hangi Gerçek İhtiyacı Karşılıyor?</h2>
            <ul class="needs-list">
                <li><span class="highlight">Stratejik Fiyatlandırma:</span> Pazar verilerine dayanarak rekabetçi fiyatlar belirleme.</li>
                <li><span class="highlight">Yatırım Riskini Azaltma:</span> Gerçekçi gelir modelleri kurma.</li>
                <li><span class="highlight">Kullanıcı Erişilebilirliği:</span> Oyuncular için ulaşılabilir fiyatlar yaratma.</li>
            </ul>

        </div>
    </div>
</div>

<style>
.hero-container {{
    position: relative; width: 100%; height: auto; min-height: 100vh;
    background-image: url("data:image/jpeg;base64,{bg}");
    background-size: cover; background-position: center; background-attachment: fixed;
    border-radius: 30px; overflow: hidden;
    display: flex; flex-direction: column; justify-content: flex-start; align-items: center;
    padding: 0; box-shadow: 0 25px 60px rgba(0,0,0,0.8);
}}

.hero-overlay {{
    position: absolute; inset: 0;
    background: linear-gradient(135deg, rgba(10, 25, 47, {op}) 0%, rgba(15, 32, 67, {op}) 100%);
    z-index: 1;
}}

.sticky-header {{
    position: sticky; top: 0;
    background: rgba(0, 0, 0, 0.4);
    width: 100%; 
    z-index: 10;
    padding: 20px 0;
    backdrop-filter: blur(10px);
}}

.brand-title {{
    font-family: 'Cinzel', serif; font-weight: 900; font-size: 4em;
    letter-spacing: 20px; color: white; margin: 0;
    text-shadow: 0 0 25px rgba(0, 210, 255, 0.7);
    text-align: center;
}}

.hero-content {{ 
    position: relative; z-index: 2; width: 100%; 
    display: flex; justify-content: center; align-items: flex-start;
    padding: 60px 80px 100px 80px;
}}

.project-text {{
    font-family: 'Cinzel', serif; font-size: 1.1em; line-height: 1.8;
    color: rgba(255, 255, 255, 0.95); text-align: justify; letter-spacing: 0.5px;
    max-width: 1200px; width: 100%;
    columns: 2; column-gap: 50px;
}}

.section-header {{
    color: #00d2ff; font-size: 1.5em; font-weight: 700; margin: 40px 0 20px 0; 
    border-left: 5px solid #00d2ff; padding-left: 20px; text-align: left;
    column-span: all;
}}

.highlight {{ color: #ffffff; font-weight: 700; }}

.story-highlight {{
    background: rgba(255, 255, 255, 0.05); padding: 25px; border-radius: 15px;
    border-right: 5px solid #00d2ff; margin: 25px 0; font-style: italic;
    column-span: all;
}}

.needs-list {{ list-style: none; padding: 0; text-align: left; column-span: all; }}

.needs-list li {{ margin-bottom: 15px; padding-left: 30px; position: relative; }}

.needs-list li::before {{ content: '◈'; position: absolute; left: 0; color: #00d2ff; }}
</style>
"""

final_html = html_template.format(bg=bg_img, op=saydamlik_orani)
display(HTML(final_html))
# Out:
# <div class="hero-container">
#     <div class="hero-overlay"></div>
#     <div class="main-content">
#         <h1 class="curved-title">
#             ANIVIA GAME INSIGHT
#         </h1>
#
#         <div class="team-wrapper">
#             <div class="member">
#                 <div class="photo-circle" style="background-image: url('data:image/jpeg;base64,...')"></div>
#                 <p class="member-name">DUYGU BOZKURT</p>
#                 <p class="member-role">Modelleme & Değerlendirme</p>
#             </div>
#             <div class="member">
#                 <div class="photo-circle" style="background-image: url('data:image/jpeg;base64,...')"></div>
#                 <p class="member-name">CEREN MICIK</p>
#                 <p class="member-role">Keşifçi Veri Analizi (EDA)</p>
#             </div>
#             <div class="member">
#                 <div class="photo-circle" style="background-image: url('data:image/jpeg;base64,...')"></div>
# ...

# %%
from IPython.display import HTML
import base64

# --- AYARLAR ---
resim_dosya_yolu = r'C:\Users\DELL\Desktop\Anivia_0.jpg' 
saydamlik_orani = 0.5

try:
    with open(resim_dosya_yolu, "rb") as f:
        encoded_string = base64.b64encode(f.read()).decode()

    hero_html = f"""
    <link href="https://fonts.googleapis.com/css2?family=Cinzel:wght@400;700;900&display=swap" rel="stylesheet">

    <div class="hero-container">
        <div class="hero-overlay"></div>
        <div class="hero-content">
            <h1 class="brand-title">ANIVIA GAME INSIGHT</h1>
            
            <div class="quad-grid">
                
                <div class="panel">
                    <h2 class="section-title">1. Veri Hikayesi</h2>
                    <p class="section-sub">"Dolarizasyon" Krizi</p>
                    <ul class="info-list">
                        <li><span class="highlight">20 Kasım 2023:</span> Steam TL yerine Dolarla satışa başladı.</li>
                        <li><span class="highlight">Karmaşa:</span> Fiyatlar kura, puana ve dil desteğine göre değişiyor.</li>
                        <li><span class="highlight">Analiz:</span> Pazarın fiyatlama davranışını inceliyoruz.</li>
                    </ul>
                </div>

                <div class="panel">
                    <h2 class="section-title">2. İş Problemi</h2>
                    <p class="section-sub">Optimum Fiyat Tahmini</p>
                    <ul class="info-list">
                        <li><span class="highlight">Soru:</span> Oyun özelliklerine bakarak ideal fiyat nasıl tahmin edilir?</li>
                        <li><span class="highlight">Yöntem:</span> Regresyon modeli ile veri analizi.</li>
                        <li><span class="highlight">Hedef:</span> Pazarın kabul edeceği dengeli fiyat.</li>
                    </ul>
                </div>

                <div class="panel">
                    <h2 class="section-title">3. Gerçek İhtiyaç</h2>
                    <p class="section-sub">Risk Yönetimi Sistemi</p>
                    <ul class="info-list">
                        <li><span class="highlight">Fiyatlandırma:</span> Bilinçli karar almak.</li>
                        <li><span class="highlight">Yatırım:</span> Emeği korumak.</li>
                        <li><span class="highlight">Erişim:</span> Oyuncular için ulaşılabilir fiyatlar.</li>
                    </ul>
                </div>

                <div class="panel story-panel">
                    <h2 class="section-title">HİKAYE & VAKA</h2>
                    <p>Yeni bir stüdyo olduğunuzu hayal edin. Harika bir oyun yaptınız ama pazar dengesiz: fiyatlar 10$ ile 70$ arasında değişiyor. Tek karar hatalı olsa yılların emeği boşa gider. Anivia Game Insight bilimsel bir denkleme dönüştürüyor.</p>
                </div>
            </div>

            <div class="note-box">
                <span class="highlight">NOT:</span> Steam'in dolar kararı, projemizin temelini oluşturur. Regresyon = Kaos → Bilim.
            </div>
        </div>
    </div>

    <style>
    .hero-container {{
        position: relative;
        width: 100%;
        height: 900px;
        background-image: url("data:image/jpeg;base64,{encoded_string}");
        background-size: cover;
        background-position: center;
        border-radius: 30px;
        overflow: hidden;
        display: flex;
        justify-content: center;
        align-items: flex-start;
        padding-top: 30px;
        box-shadow: 0 25px 60px rgba(0,0,0,0.7);
    }}

    .hero-overlay {{
        position: absolute;
        inset: 0;
        background: linear-gradient(135deg, 
                    rgba(10, 25, 47, {saydamlik_orani}) 0%, 
                    rgba(20, 68, 106, {saydamlik_orani * 0.9}) 100%);
        z-index: 1;
    }}

    .hero-content {{
        position: relative;
        z-index: 2;
        width: 92%;
        height: 100%;
        display: flex;
        flex-direction: column;
        justify-content: space-between;
    }}

    .brand-title {{
        font-family: 'Cinzel', serif;
        font-weight: 900;
        font-size: 2.8em;
        letter-spacing: 12px;
        color: #ffffff;
        margin: 0 0 20px 0;
        text-transform: uppercase;
        text-align: center;
        text-shadow: 0 0 20px rgba(0, 210, 255, 0.6);
    }}

    .quad-grid {{
        display: grid;
        grid-template-columns: repeat(2, 1fr);
        gap: 20px;
        flex-grow: 1;
    }}

    .panel {{
        background: rgba(255, 255, 255, 0.03);
        padding: 20px;
        border-radius: 12px;
        border: 1px solid rgba(255, 255, 255, 0.1);
        backdrop-filter: blur(5px);
        transition: all 0.3s ease;
        overflow: hidden;
    }}

    .panel:hover {{
        background: rgba(0, 210, 255, 0.08);
        border-color: rgba(0, 210, 255, 0.4);
        transform: translateY(-3px);
    }}

    .section-title {{
        font-family: 'Cinzel', serif;
        font-weight: 700;
        font-size: 1.2em;
        color: #00d2ff;
        margin: 0 0 5px 0;
        letter-spacing: 1px;
    }}

    .section-sub {{
        font-family: 'Cinzel', serif;
        font-size: 0.85em;
        color: rgba(255, 255, 255, 0.6);
        margin: 0 0 12px 0;
        font-style: italic;
    }}

    .info-list {{
        list-style: none;
        padding: 0;
        margin: 0;
    }}

    .info-list li {{
        font-family: 'Cinzel', serif;
        font-size: 0.78em;
        color: rgba(255, 255, 255, 0.8);
        margin-bottom: 8px;
        line-height: 1.4;
        border-bottom: 1px solid rgba(255, 255, 255, 0.03);
        padding-bottom: 5px;
    }}

    .highlight {{
        color: #00d2ff;
        font-weight: 700;
    }}

    .story-panel {{
        grid-column: span 2;
        background: rgba(0, 210, 255, 0.05);
        border: 1px solid rgba(0, 210, 255, 0.2);
    }}

    .story-panel p {{
        font-family: 'Cinzel', serif;
        font-size: 0.85em;
        color: rgba(255, 255, 255, 0.9);
        line-height: 1.5;
        margin: 0;
        text-align: justify;
    }}

    .note-box {{
        margin-top: 15px;
        padding: 15px;
        background: rgba(0, 210, 255, 0.06);
        border-left: 4px solid #00d2ff;
        border-radius: 8px;
        text-align: center;
    }}

    .note-box span {{
        font-family: 'Cinzel', serif;
        font-size: 0.85em;
        color: rgba(255, 255, 255, 0.85);
        font-weight: 700;
    }}
    </style>
    """
    display(HTML(hero_html))

except Exception as e:
    print(f"Hata: {e}")
# Out:
#     <link href="https://fonts.googleapis.com/css2?family=Cinzel:wght@400;700;900&display=swap" rel="stylesheet">
#
#     <div class="hero-container">
#         <div class="hero-overlay"></div>
#         <div class="hero-content">
#             <h1 class="brand-title">ANIVIA GAME INSIGHT</h1>
#
#             <div class="quad-grid">
#
#                 <div class="panel">
#                     <h2 class="section-title">1. Veri Hikayesi</h2>
#                     <p class="section-sub">"Dolarizasyon" Krizi</p>
#                     <ul class="info-list">
#                         <li><span class="highlight">20 Kasım 2023:</span> Steam TL yerine Dolarla satışa başladı.</li>
#                         <li><span class="highlight">Karmaşa:</span> Fiyatlar kura, puana ve dil desteğine göre değişiyor.</li>
#                         <li><span class="highlight">Analiz:</span> Pazarın fiyatlama davranışını inceliyoruz.</li>
#                     </ul>
#                 </div>
#
# ...

# %% [markdown]
# # Proje Klasör Yapısı
#
# ```text
# YBS-MAKİNE-OGRENMESİ/
# ├── ANIVIA/
# │   ├── figures/
# │   │   ├── cihaz_turu_barchart_pie_plotly.html
# │   │   ├── dil_destegi_pasta_yanyana_plotly.html
# │   │   ├── dil_sayisi_vs_fiyat_scatter_trendline_plotly.html
# │   │   ├── fiyat_vs_cihaz_turu_violin_pie_plotly.html
# │   │   ├── oyun_turu_vs_cihaz_turu_stacked_bar_plotly.html
# │   │   ├── platform_barchart_pie_plotly.html
# │   │   ├── platform_fiyat_boxplot_plotly.html
# │   │   ├── puan_durumu_barchart_pie_plotly.html
# │   │   ├── puan_durumu_vs_fiyat_boxplot_plotly.html
# │   │   └── yas_barchart_pie_plotly.html
# │   ├── Resimler/
# │   │   ├── Anivia_0.jpg
# │   │   ├── BETÜL 1.jpeg
# │   │   ├── CEREN 1.jpeg
# │   │   ├── DUYGU 1.jpeg
# │   │   ├── kapak.jpeg
# │   │   └── kolaj_gorsel.jpg
# │   ├── web-scraping-data/
# │   │   ├── ANIVIA_GAME_INSIGHT_CLEANED.csv
# │   │   ├── ANIVIA_GAME_INSIGHT_FINAL.csv
# │   │   ├── epicveri1.csv
# │   │   ├── NINTENDO.csv
# │   │   ├── nintendo2.csv
# │   │   ├── PSVERI1SONHALİ.csv
# │   │   ├── README.md
# │   │   ├── steam.csv
# │   │   ├── XBOX_TUM_OYUNLAR.csv
# │   │   └── xbox2.csv
# │   ├── anivia_temiz_data.csv
# │   ├── anivia.ipynb
# │   ├── projeson.ipynb
# │   └── README.md
# ├── ders03
# └── README.md
